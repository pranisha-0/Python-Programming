# %%
#q1 : sum of list elements
lst = []
n = int(input("Enter a number: "))
for i in range(1, n+1):
    num = int(input(f"Enter num{i}: "))
    lst.append(num)
print(f"Your list is: {lst}.")
sum = 0
for i in range(0, n):
    sum = sum + lst[i]
print(f"The sum of the list is: {sum}.")
# Out:
# Your list is: [1, 2, 3, 4].
# The sum of the list is: 10.

# %%
#Q2 : max and min in list
ls = []
n = int(input("ENter a number: "))
for i in range(0, n):
    nm = int(input(f"Enter num{i+1}: "))
    ls.append(nm)
print(f"Your list is {ls}")

max = ls[0]
for i in range(0, n):
    if ls[i] > max:
        max = ls[i]
print(f"THe max num from list is {max}.")

min = ls[0]
for i in range(0, n):
    if ls[i] < min:
        min = ls[i]
print(f"The min num from list is {min}.")
# Out:
# Your list is [335, 654, 754, 65]
# THe max num from list is 754.
# The min num from list is 65.

# %%
#q3 : count no of even and odd nums from list
list = []
c_e = 0
c_o = 0
n =int(input("ENter a number: "))
for i in range(0, n):
    numr = int(input(f"ENter num{i+1}: "))
    list.append(numr)
for i in range(0, n):
    if list[i] % 2 == 0:
        c_e += 1
    else:
        c_o += 1
print(f"no. of even numbers is {c_e} & no. of odd numbers is {c_o}.")
# Out:
# no. of even numbers is 2 & no. of odd numbers is 3.

# %%
#q4 : reverse a list

normal_ls = []
reverse_ls = []
n = int(input("Enter a num: "))
for i in range(0, n):
    numb = int(input(f"ENter num{i+1}: "))
    normal_ls.append(numb)
for i in range(n, 0, -1):
    reverse_ls.append(normal_ls[i-1])
print(f"Your normal list is {normal_ls}.")
print(f"Your reversed list is {reverse_ls}.")


rev = []
for i in range(n-1, -1, -1):
    temp = normal_ls[i]
    rev.append(temp)
print(f"Your reversed list is {rev}.")
# Out:
# Your normal list is [2, 4, 5].
# Your reversed list is [5, 4, 2].
# Your reversed list is [5, 4, 2].

# %%
####reverse works like this
nor = [2, 3, 4, 5]
rev = []
how = []
for i in range(4, 0, -1):
    rev.append(nor[i-1])

how.append(nor[4-1])
how.append(nor[3-1])
how.append(nor[2-1])
how.append(nor[0])
print(rev)
print(how)
print(nor)

#print(nor[-3])
# Out:
# [5, 4, 3, 2]
# [5, 4, 3, 2]
# [2, 3, 4, 5]
# 3

# %%
#q5 : factorial using function
def factorial(a):
    if a == 0 and a == 1:
        return 1
    else:
        f = 1
        for i in range(1, a+1):
            f = f*i
        return f

n = int(input("ENter a number: ")) 
if n>0:
    fact = factorial(n)
    print("The factorial of", n, "is", fact)
else:
    print("Factorial of negative number doesn't exist.")
# Out:
# The factorial of 5 is 120

# %%
#q6 : prime checker
def is_Prime(x):
    count = 0
    for i in range(1, x+1):
        if x%i == 0:
            count += 1
    if count == 2:
        return True
    else:
        return False

n = int(input("Enter a number: "))
check = is_Prime(n)
print(check)
# Out:
# True

# %%
#q7 : remove duplicates
my_list = []
n = int(input("Enter a number: "))
for i in range(0, n):
    mem = input(f"Enter element{i+1}: ")
    my_list.append(mem)
no_dupes = []
for i in my_list:
    if i not in no_dupes:
        no_dupes.append(i)
print("original list:", my_list)
print("no duplicates:", no_dupes)
# Out:
# original list: ['the', 'a', 'b', 'b', 'a']
# no duplicates: ['the', 'a', 'b']

# %%
#q8 : count occurrence of elements in list
my_list = []
n = int(input("Enter a number: "))
for i in range(0, n):
    mem = input(f"Enter element{i+1}: ")
    my_list.append(mem)
done = []
for i in range(0, n):
    count = 0
    for j in my_list:
        if my_list[i] == j:
            count += 1
    if my_list[i] not in done:
        print(f"frequency of {my_list[i]} -> {count}")
        done.append(my_list[i])
# Out:
# frequency of b -> 1
# frequency of a -> 3
# frequency of n -> 2

# %%
#q10 : student marks analyzer
n = int(input("Enter the number of students: "))
marks = []
for i in range(n):
    mark = int(input(f"Enter marks for student {i+1}: "))
    marks.append(mark)
def total_marks(n):
    total = sum(n)
    return total
def average_marks(n):
    avg = sum(n)/len(n)
    return avg
def highest_marks(n):
    high = max(n)
    return high
def lowest_marks(n):
    low = min(n)
    return low
def passed(n):
    p_c = 0
    for mark in n:
        if mark >= 40:
            p_c += 1
    return p_c

print(f"Marks of students: {marks}")
print(f"Total marks: {total_marks(marks)}")
print(f"Average marks: {average_marks(marks)}")
print(f"Highest marks: {highest_marks(marks)}")
print(f"Lowest marks: {lowest_marks(marks)}")
print(f"Number of students passed: {passed(marks)}")
# Out:
# Marks of students: [34, 58]
# Total marks: 92
# Average marks: 46.0
# Highest marks: 58
# Lowest marks: 34
# Number of students passed: 1

# %%
def search(lst, key):
    for index, value in enumerate(lst):
        if value == key:
            return index
    return "Element not found."


# Example usage
items = [10, 25, 7, 40]
print(search(items, 4))   # Output: 2
# Out:
# Element not found.
