# %%
ls = [1, 5, 6, 38, 67, "ell", 9]
print(ls[0])
for i in ls:
    print(i, end = " ")
print("\n")
print(ls[-3])
if "3" in ls:
    print("whatever")
else:
    print("nonsense")
# Out:
# 1
# 1 5 6 38 67 ell 9
#
# 67
# nonsense

# %%
print(ls)
type(ls)
# Out:
# [1, 5, 6, 38, 67, 'ell', 9]
# list

# %% [markdown]
# n3gative index diyeko xa vane positiv index ma lagnu by len(..)-x

# %%
#slicing
print(ls[1:4]) #1 to 4 index print garxa
print(ls[1:4:2]) #1 to 4 index print garxa but 2 ko gap ma print garxa
print(ls[:-2]) #last 2 index print garxa
len(ls)
# Out:
# [5, 6, 38]
# [5, 38]
# [1, 5, 6, 38, 67]
# 7

# %%
lis = []
for i in range(1, 11):
    if i %2 == 0:
        lis.append(i*i)
print(lis)
# Out:
# [4, 16, 36, 64, 100]

# %% [markdown]
# list methods.
# list_name.append(x) _> x lai list ma add garxa
# l.sort() le ascending order ma srt garxa
# l.sort(reverse=True) le descending order ma sort garxa
# l.reverse() list lai reverse garxa
# l.index() le index ko value dinxa
# l.count() count garxa any elements ist ma how many times repeat vako xa
# m = l.copy() "l" list ko contents "m" list ma cpy garxa
# l.insert(1, 99) indexx 1 ma vako value lai 99 sanga replacegarxa
# l.extend(m) m lai l sanga jodxa
