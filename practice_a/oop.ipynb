# %% [markdown]
# #class vaneko bluprint , template ho
# #objects vaneko blueprint ko instance ho
# '''eg: let euta car vanne class xa, tesko name, modelno, etc vaneko tesko attributes ho,
#  ra tesle jj kaam garxa like horn, brake, accelerate vaneko tesko methods ho

# %%
class dog:
    def __init__(self, name, age, breed):
        self.name = name
        self.age = age
        self.breed = breed
    def bark(self):
        print("woof")
    def get_info(self):
       print(f"{self.name} is a {self.age} yr old dog. \n Breed: {self.breed}")
dog1 = dog("Tommy", 3, "Golden Retriever")
dog2 = dog("tiger", 6, "german shepard")
print(dog1.get_info())
